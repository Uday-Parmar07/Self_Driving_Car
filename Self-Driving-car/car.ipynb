# %%
import os
import gym
import stable_baselines3
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import pygame

pygame.init()
environment ="CarRacing-v2"
env = gym.make(environment,render_mode = "human")

# %%
env = DummyVecEnv([lambda:env])
log_path = os.path.join('training' , 'logs')
ppo_path = os.path.join("training" , "saved models", "car_PPO_new")
model = PPO.load(ppo_path,env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to training\logs\PPO_12
# -----------------------------
# | time/              |      |
# |    fps             | 29   |
# |    iterations      | 1    |
# |    time_elapsed    | 70   |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 2          |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11188968 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.88       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.0194     |
# |    std                  | 0.73       |
# ...

# %%
ppo_path = os.path.join("training" , "saved models", "car_PPO_new3")
model.save(ppo_path)

# %%
del model

# %%
ppo_path = os.path.join("training" , "saved models", "car_PPO_new3")
model = PPO.load(ppo_path,env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
evaluate_policy(model, env, n_eval_episodes=2,render=True)
# Out:
# (876.0837196670473, 31.316262524574995)

# %%
env.close()
